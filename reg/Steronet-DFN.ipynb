# %%
import itertools
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection
import numpy as np

def main():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='polar')
    x = np.radians(np.arange(0, 360, 40))
    y = np.random.random(x.size)
    z = np.random.random(y.size)
    cmap = plt.get_cmap('cool')
    coll = colored_bar(x, y, z, ax=ax, width=np.radians(10), cmap=cmap)
    fig.colorbar(coll)
    ax.set_yticks([0.5, 1.0])
    plt.show()   

def colored_bar(left, height, z=None, width=0.8, bottom=0, ax=None, **kwargs):
    if ax is None:
        ax = plt.gca()
    width = itertools.cycle(np.atleast_1d(width))
    bottom = itertools.cycle(np.atleast_1d(bottom))
    rects = []
    for x, y, h, w in zip(left, bottom, height, width):
        rects.append(Rectangle((x,y), w, h))
    coll = PatchCollection(rects, array=z, **kwargs)
    ax.add_collection(coll)
    ax.autoscale()
    return coll

if __name__ == '__main__':
    main()

# %%
# Compute pie slices
w1=2
w2=4
w_m=2.001
theta = np.radians([67,97,112,142,248,277,292,322])
radii = [w2,w1,w1,w_m,w2,w1,w1,w_m]
width = np.radians([15,11,11,11,15,11,11,11])

plt.close()
fig = plt.figure(figsize=(7.5,7.5))
ax = plt.subplot(111, projection='polar')
ax.set_theta_zero_location("N")
ax.set_theta_direction(-1)
ax.set_yticks(np.arange(0,5,1))
ax.set_yticklabels([])
ax.set_xticks(np.radians(np.arange(0,360,15)))
ax.set_xticklabels((np.arange(0,360,15)),weight='bold')

flag1 = False
flag2 = False
flag3 = False

bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    if(r==4):
        bar.set_facecolor(color="blue")
        if (flag1==False):
            bar.set_label('Set N70')
            flag1=True
    elif(r==2.001):
        bar.set_facecolor(color="green")
        if (flag2==False):
            bar.set_label('Set N140')
            flag2=True
    else:
        bar.set_facecolor(color='red')
        if (flag3==False):
            bar.set_label('Set N105')
            flag3=True
    print(bar)
    #bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.8)
plt.legend(loc='lower center')
plt.title('Fracture sets Modelled in DFN',y=1.1,weight='bold')
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 20

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title|

plt.subplots_adjust(left=0.1, bottom=None, right=None, top=None, wspace=0.39, hspace=0.3)
plt.savefig('stereonet-1.pdf',dpi=500, bbox_inches='tight')
#plt.show()
# Out:
# Rectangle(1.03847,0;0.261799x4)
# Rectangle(1.59698,0;0.191986x2)
# Rectangle(1.85878,0;0.191986x2)
# Rectangle(2.38237,0;0.191986x2.001)
# Rectangle(4.19752,0;0.261799x4)
# Rectangle(4.73857,0;0.191986x2)
# Rectangle(5.00037,0;0.191986x2)
# Rectangle(5.52397,0;0.191986x2.001)

# %%
plt.close()
